# %%
import os
from dotenv import load_dotenv

# 1. .env 파일 로드
load_dotenv()

# 2. .env에 적힌 이름 그대로 가져와서 LangChain 표준 변수에 할당하기
# (토씨 하나 안 틀리고 똑같이 맞춰야 합니다)
os.environ["LANGCHAIN_TRACING_V2"] = os.getenv("LANGSMITH_TRACING")
os.environ["LANGCHAIN_ENDPOINT"] = os.getenv("LANGSMITH_ENDPOINT")
os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGSMITH_API_KEY")
os.environ["LANGCHAIN_PROJECT"] = os.getenv("LANGSMITH_PROJECT")

# 3. 제대로 들어갔는지 확인 (디버깅용)
print(f"체크 - API KEY: {os.getenv('LANGCHAIN_API_KEY')[:10] if os.getenv('LANGCHAIN_API_KEY') else 'None'}...")
print(f"체크 - 프로젝트: {os.getenv('LANGCHAIN_PROJECT')}")
# Out:
# 체크 - API KEY: lsv2_pt_94...
# 체크 - 프로젝트: catcher-llm

# %%
from langsmith import traceable
from langsmith import Client

# 1. 테스트용 함수 만들기
@traceable # 이 함수가 실행되면 LangSmith로 데이터가 전송됩니다.
def test_langsmith_connection():
    return "LangSmith 연결 성공!"

# 2. 함수 실행 (이때 프로젝트가 생성됩니다)
print("로그 전송 중...")
result = test_langsmith_connection()
print(f"함수 실행 결과: {result}")

# 3. 내 프로젝트 리스트 확인하기 (코드로 확인)
client = Client()
projects = list(client.list_projects())
print(f"현재 내 계정의 프로젝트들: {[p.name for p in projects]}")
# Out:
# 로그 전송 중...
# 함수 실행 결과: LangSmith 연결 성공!
# 현재 내 계정의 프로젝트들: ['selfReport-rag-v1-d442c3da', 'kca-rag-v1-d2a40280', 'model-comparison-repeat-cfd7b115', 'model-comparison-394876c2', 'model-comparison-0616bc4f', 'groundedness-combined-39b331c0', 'groundedness-eval-e6193933', 'groundedness-combined-f89986ec', 'groundedness-eval-508e2984', 'heuristic-eval-2c749ee3', 'custom-evaluators-b04ddad7', 'custom-evaluators-bc941d86', 'custom-evaluators-838994a5']
