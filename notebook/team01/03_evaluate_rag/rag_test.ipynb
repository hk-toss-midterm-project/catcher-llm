# %%
from langchain_community.vectorstores import FAISS
from langchain_openai import OpenAIEmbeddings

embeddings = OpenAIEmbeddings()

vectorstore = FAISS.load_local(
    "vectorstore/faiss_index",
    embeddings,
    allow_dangerous_deserialization=True
)

retriever = vectorstore.as_retriever(search_kwargs={"k": 3})
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 6
#       2 from langchain_openai import OpenAIEmbeddings
#       3
#       4 embeddings = OpenAIEmbeddings()
#       5
# ----> 6 vectorstore = FAISS.load_local(
#       7     "vectorstore/faiss_index",
#       8     embeddings,
#       9     allow_dangerous_deserialization=True
#
# File c:\Users\user\catcher\catcher-llm\.venv\Lib\site-packages\langchain_community\vectorstores\faiss.py:1205, in FAISS.load_local(cls, folder_path, embeddings, index_name, allow_dangerous_deserialization, **kwargs)
#    1203 # load index separately since it is not picklable
#    1204 faiss = dependable_faiss_import()
# -> 1205 index = faiss.read_index(str(path / f"{index_name}.faiss"))
#    1207 # load docstore and index_to_docstore_id
#    1208 with open(path / f"{index_name}.pkl", "rb") as f:
#
# File c:\Users\user\catcher\catcher-llm\.venv\Lib\site-packages\faiss\swigfaiss_avx2.py:12913, in read_index(*args)
#   12912 def read_index(*args):
# > 12913     return _swigfaiss_avx2.read_index(*args)
#
# RuntimeError: Error in __cdecl faiss::FileIOReader::FileIOReader(const char *) at D:\a\faiss-wheels\faiss-wheels\third-party\faiss\faiss\impl\io.cpp:70: Error: 'f' failed: could not open vectorstore\faiss_index\index.faiss for reading: No such file or directory
