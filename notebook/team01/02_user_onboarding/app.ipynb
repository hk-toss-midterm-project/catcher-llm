# %%
import pandas as pd


# 1) 데이터 불러오기
members = pd.read_csv(r"C:\Users\user\catcher\catcher-llm\data\raw\csv\members_v1.csv")
consumption = pd.read_csv(r"C:\Users\user\catcher\catcher-llm\data\raw\csv\consumption_v1.csv")
