# %%
import os
import sys
from pathlib import Path


# 프로젝트 루트 경로를 찾아 src 폴더를 sys.path에 추가합니다.
def find_project_root() -> Path:
    curr = Path.cwd()
    for parent in [curr] + list(curr.parents):
        if (parent / "pyproject.toml").exists():
            return parent
    return curr


PROJECT_ROOT = find_project_root()
src_dir = str(PROJECT_ROOT / "src")
if src_dir not in sys.path:
    sys.path.insert(0, src_dir)

os.environ.setdefault("LANGSMITH_TRACING", "false")
# Out:
# 'true'

# %%
from pathlib import Path
from catcher_llm.config.settings import get_settings
from catcher_llm.retrievers.vectorstore import build_local_vectorstore

file_path = Path(PROJECT_ROOT / "data/raw/pdf/saving_tips/1.pdf")
dir_path = PROJECT_ROOT / "data/raw/pdf/saving_tips"

# vectorstore.py 에서 정의한 FAISS 기반 빌더 사용

config = get_settings()
vectorstore = build_local_vectorstore(
    raw_data_dir=dir_path,
    chunk_size=config.rag_chunk_size,
    chunk_overlap=config.rag_chunk_overlap
)

if vectorstore:
    if hasattr(vectorstore, "store"):
        num_docs = vectorstore.index.ntotal if hasattr(vectorstore, "index") else len(getattr(vectorstore, "store", []))
    elif hasattr(vectorstore, "index"):
        num_docs = vectorstore.index.ntotal
    else:
        num_docs = "알 수 없음"
    print(f"벡터스토어 생성 완료. 문서 수: {num_docs}")

    # 검색 기능 테스트
    query = "식비 절약 팁"
    results = vectorstore.similarity_search(query, k=3)

    print(f"\n[ 검색 질의: {query} ]")
    for idx, res in enumerate(results, start=1):
        print(f"\n--- 검색 결과 {idx} ---")
        print(res.page_content)
else:
    print("생성된 벡터스토어가 없습니다.")
# Out:
# 벡터스토어 생성 완료. 문서 수: 74
#
# [ 검색 질의: 식비 절약 팁 ]
#
# --- 검색 결과 1 ---
# 절약 생활을 시작할 때 가족의 도움 없이 주부 혼자의 노력만으로 가장 쉽게 줄일 수 있는 비용이 식
# 비입니다. 식비를 절약하기 위해 아래 3가지를 기억하고, 실천해보세요.
# 첫째, 계획적인 장보기를 통해 식재료를 저렴하게 구입해야합니다
# 둘째, 구입한 식재료를 요리하기 전까지 맛있게 보존해야합니다
# #
# 쇼핑 전에는 냉장고 안을 체크 한 후 장볼 재료를 메모합니다. 마트에 자주 가는 것만으로도 식비는
# 늘어나기 때문에 마트 가는 횟수를 줄여야하며, 장보기는 가급적 혼자 하는 것이 식비절약에 도움이
# 됩니다. 또한 가게마다 특징이 있는데 예컨대 봄가을처럼 채소가 저렴한 계절에는 마트보다 시장이
# 저렴합니다. 시장 상인들은 매일같이 농산물 도매시장을 가기 때문에 저렴한 매입가를 판매가에 바
# 로 반영할 수 있기 때문입니다. 반면에 한겨울 한파 때문에 채소 가격이 급등했다면 시장보다 마트
# 가 더 저렴합니다. 일반적으로 마트에서는 고추 한 봉은 990원 등으로 채소도 정가에 판매하기 때문
# 에, 채소가격이 급등해도 일년 365일 비슷한 가격에 서비스하고 적자 분은 다른 매장에서 충당하기
# 때문입니다.
# 절약생활의 시작은 식비절약부터
# 
# 26. 4. 20. 오후  3:39 소비자시대  웹진
# https://www.kca.go.kr/webzine/board/view?menuId=MENU00305&linkId=144&div=kca_2003 3/9
#
# --- 검색 결과 2 ---
# 고 화려하게 사는 모습 또한 보여주고 싶은 것이 사람 마음이다 보니 이번 달도 우리 집 가계부는 적
# 자입니다.
# 절약이라고 하면 김치하나에 밥을 먹는다거나 대기전력 아끼려고 매번 콘센트를 뽑는 등 극단적으
# 로 아끼는 생활을 떠올립니다. 하지만 밥을 먹고 전기를 사용하는 것은 일상생활에 꼭 필요한 지출
# 이기 때문에, 온가족에게 스트레스를 주면서까지 돈을 아끼는 것은 인색한 것이지 절약이 아니라고
# 생각합니다. 양동이에 구멍이 숭숭 뚫려있으면 물을 채울 수 없는 것처럼, 새어나가는 돈이 많으면
# 저축을 할 수 없습니다. 즉 절약이란 돈을 안 쓰는 것이 아니라 낭비되는 돈을 모아 꼭 필요한 곳에
# 쓰는 것입니다.
# 대부분의 사람들은 돈이 모이지 않는 현실에 불안해하지만 정작 자신이 일상생활에서 생각없이 써
# 서 새어나가는 돈에 대해서는 매우 둔감한 편입니다. ‘크게 소비하는 비용’에만 집중할 뿐, 정작 일
# 상생활에서 술술 새어나가는 돈에 대해서는 신경 쓰지 않기 때문입니다. 하지만 푼돈이 모여야 목돈
# 이 되는 것처럼, 생활 속의 작은 절약 습관이 모여야 큰 절약으로 연결되어 미래에 투자할 수 있는 법
# 입니다.
# # 절약과 인색한 것은 다르다
# 
# 26. 4. 20. 오후  3:39 소비자시대  웹진
# https://www.kca.go.kr/webzine/board/view?menuId=MENU00305&linkId=144&div=kca_2003 2/9
#
# --- 검색 결과 3 ---
# 살림만잘해도돈이모인다,초절약살림
# 법
# 글조윤경 <‘초절약 살림법’ 저자, 블로그 ‘털팽이의 정리법’운영>
# 우리는 알뜰살뜰 살림해서 집도 사고 차도 바꾸는 행복한 미래를 꿈꿉니다. 하지만 특별히 사치하는
# 타입도 아닌데 저축은 쉽지 않습니다. 주말이면 남들처럼 가족과 외식도 하고 싶고, 아등바등 아끼
# 면서 사는 모습을 남들에게 보이고 싶지도 않습니다. 절약도 하고 싶고 저축도 하고 싶지만, 당당하
# 이 달의 추천정보
# 
#  1일간 열지 않음 
# 26. 4. 20. 오후  3:39 소비자시대  웹진
# https://www.kca.go.kr/webzine/board/view?menuId=MENU00305&linkId=144&div=kca_2003 1/9

# %%
if vectorstore:
    print(f"벡터스토어 생성 완료. 문서 수: {vectorstore.index.ntotal if hasattr(vectorstore, "index") else len(getattr(vectorstore, "store", []))}")

    # 검색 기능 테스트
    query = "절약하는 법"
    results = vectorstore.similarity_search(query, k=3)

    print(f"\n[ 검색 질의: {query} ]")
    for idx, res in enumerate(results, start=1):
        print(f"\n--- 검색 결과 {idx} ---")
        print(res.page_content)
else:
    print("생성된 벡터스토어가 없습니다.")
# Out:
# 벡터스토어 생성 완료. 문서 수: 74
#
# [ 검색 질의: 절약하는 법 ]
#
# --- 검색 결과 1 ---
# 절약 생활을 시작할 때 가족의 도움 없이 주부 혼자의 노력만으로 가장 쉽게 줄일 수 있는 비용이 식
# 비입니다. 식비를 절약하기 위해 아래 3가지를 기억하고, 실천해보세요.
# 첫째, 계획적인 장보기를 통해 식재료를 저렴하게 구입해야합니다
# 둘째, 구입한 식재료를 요리하기 전까지 맛있게 보존해야합니다
# #
# 쇼핑 전에는 냉장고 안을 체크 한 후 장볼 재료를 메모합니다. 마트에 자주 가는 것만으로도 식비는
# 늘어나기 때문에 마트 가는 횟수를 줄여야하며, 장보기는 가급적 혼자 하는 것이 식비절약에 도움이
# 됩니다. 또한 가게마다 특징이 있는데 예컨대 봄가을처럼 채소가 저렴한 계절에는 마트보다 시장이
# 저렴합니다. 시장 상인들은 매일같이 농산물 도매시장을 가기 때문에 저렴한 매입가를 판매가에 바
# 로 반영할 수 있기 때문입니다. 반면에 한겨울 한파 때문에 채소 가격이 급등했다면 시장보다 마트
# 가 더 저렴합니다. 일반적으로 마트에서는 고추 한 봉은 990원 등으로 채소도 정가에 판매하기 때문
# 에, 채소가격이 급등해도 일년 365일 비슷한 가격에 서비스하고 적자 분은 다른 매장에서 충당하기
# 때문입니다.
# 절약생활의 시작은 식비절약부터
# 
# 26. 4. 20. 오후  3:39 소비자시대  웹진
# https://www.kca.go.kr/webzine/board/view?menuId=MENU00305&linkId=144&div=kca_2003 3/9
#
# --- 검색 결과 2 ---
# 고 화려하게 사는 모습 또한 보여주고 싶은 것이 사람 마음이다 보니 이번 달도 우리 집 가계부는 적
# 자입니다.
# 절약이라고 하면 김치하나에 밥을 먹는다거나 대기전력 아끼려고 매번 콘센트를 뽑는 등 극단적으
# 로 아끼는 생활을 떠올립니다. 하지만 밥을 먹고 전기를 사용하는 것은 일상생활에 꼭 필요한 지출
# 이기 때문에, 온가족에게 스트레스를 주면서까지 돈을 아끼는 것은 인색한 것이지 절약이 아니라고
# 생각합니다. 양동이에 구멍이 숭숭 뚫려있으면 물을 채울 수 없는 것처럼, 새어나가는 돈이 많으면
# 저축을 할 수 없습니다. 즉 절약이란 돈을 안 쓰는 것이 아니라 낭비되는 돈을 모아 꼭 필요한 곳에
# 쓰는 것입니다.
# 대부분의 사람들은 돈이 모이지 않는 현실에 불안해하지만 정작 자신이 일상생활에서 생각없이 써
# 서 새어나가는 돈에 대해서는 매우 둔감한 편입니다. ‘크게 소비하는 비용’에만 집중할 뿐, 정작 일
# 상생활에서 술술 새어나가는 돈에 대해서는 신경 쓰지 않기 때문입니다. 하지만 푼돈이 모여야 목돈
# 이 되는 것처럼, 생활 속의 작은 절약 습관이 모여야 큰 절약으로 연결되어 미래에 투자할 수 있는 법
# 입니다.
# # 절약과 인색한 것은 다르다
# 
# 26. 4. 20. 오후  3:39 소비자시대  웹진
# https://www.kca.go.kr/webzine/board/view?menuId=MENU00305&linkId=144&div=kca_2003 2/9
#
# --- 검색 결과 3 ---
# 살림만잘해도돈이모인다,초절약살림
# 법
# 글조윤경 <‘초절약 살림법’ 저자, 블로그 ‘털팽이의 정리법’운영>
# 우리는 알뜰살뜰 살림해서 집도 사고 차도 바꾸는 행복한 미래를 꿈꿉니다. 하지만 특별히 사치하는
# 타입도 아닌데 저축은 쉽지 않습니다. 주말이면 남들처럼 가족과 외식도 하고 싶고, 아등바등 아끼
# 면서 사는 모습을 남들에게 보이고 싶지도 않습니다. 절약도 하고 싶고 저축도 하고 싶지만, 당당하
# 이 달의 추천정보
# 
#  1일간 열지 않음 
# 26. 4. 20. 오후  3:39 소비자시대  웹진
# https://www.kca.go.kr/webzine/board/view?menuId=MENU00305&linkId=144&div=kca_2003 1/9
